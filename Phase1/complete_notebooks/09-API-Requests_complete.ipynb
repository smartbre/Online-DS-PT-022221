# %% [markdown]
# # APIs - Gathering Data Using Requests

# %% [markdown]
# ## The Many Use Cases For APIs
#
# APIs can be used for many things - much more than just retrieving information. Twilio has an API that allows you to write a script to send text messages to people. GitHub has an API for creating new repositories. Many services have APIs allowing computers to automate tasks that a person might otherwise have to do through a website - whether uploading a photo to Flickr, searching for a company name in a state database, or getting a list of garbage collection times for a municipality.

# %% [markdown]
# ## Limitations of APIs
#
# When working with APIs, there are some limitations you have to be aware of - especially relating to scope and scale.
#
# * **Scope** - Just because a company has an API and has information, it doesn't mean you can get all of the information you might want through their API
#
# * **Scale** - Some APIs are provided for free as a public service. Others you have to pay for, or allow you to perform activities (like sending a text message) that you pay for. Make sure that you know what the rate limits are and that your use case isn't going to need more API calls than you will be able to make.
#
# What else is good to know? **Every API is different!** There are some standards out there in terms of documentation and usage... but it's like the wild west - rapid expansion with few rules.
#
# With all that out of the way - Let's take a look at the `requests` library and its uses.

# %% [markdown]
# ### "Requests is the only Non-GMO HTTP library for Python, safe for human consumption."
#
# > "Requests allows you to send organic, grass-fed HTTP/1.1 requests, without the need for manual labor."
#
# Straight from the `requests` [documentation](https://pypi.org/project/requests/)

# %% [markdown]
# ### Types of Requests
#
# We will mostly use GET requests in order to get data, but there are other options.
#
# ![CRUD image from IntelliPaat](https://intellipaat.com/mediaFiles/2015/08/MongoDB-CRUD-operations.jpg)
#
# That's right - CRUD summarizes the kinds of requests you can make with most APIs.
#
# Let's say you are looking at an API for a car rental company like Hertz or Zipcar - the following different requests could generate these different responses:
#
# | Request               | Result                               | In CRUD Terms |
# | --------------------- | ------------------------------------ | ------------- |
# | GET /stores/          | User sees the list of stores         | Read          |
# | GET /rentals/         | User sees the history of car rentals | Read          |
# | POST /rentals/        | User rents a car                     | Create        |
# | PUT /rentals/{id}/    | User changes destination store       | Update        |
# | DELETE /rentals/{id}/ | User cancels the active car rental   | Delete        |

# %% [markdown]
# ### Let's get started!

# %%
import requests

# %%
# Don't already have the library? Uncomment the below code and install it locally
#!pip install requests

# %%
# Create a GET request, then check the type of object

r = requests.get('https://api.github.com/events') 
type(r)
# Out:
# requests.models.Response

# %%
# So what does this look like?
r.text
# Out:
# '[{"id":"15694452069","type":"PullRequestEvent","actor":{"id":23436747,"login":"adongare","display_login":"adongare","gravatar_id":"","url":"https://api.github.com/users/adongare","avatar_url":"https://avatars.githubusercontent.com/u/23436747?"},"repo":{"id":116037332,"name":"projecttacoma/cqm-parsers","url":"https://api.github.com/repos/projecttacoma/cqm-parsers"},"payload":{"action":"opened","number":142,"pull_request":{"url":"https://api.github.com/repos/projecttacoma/cqm-parsers/pulls/142","id":601097061,"node_id":"MDExOlB1bGxSZXF1ZXN0NjAxMDk3MDYx","html_url":"https://github.com/projecttacoma/cqm-parsers/pull/142","diff_url":"https://github.com/projecttacoma/cqm-parsers/pull/142.diff","patch_url":"https://github.com/projecttacoma/cqm-parsers/pull/142.patch","issue_url":"https://api.github.com/repos/projecttacoma/cqm-parsers/issues/142","number":142,"state":"open","locked":false,"title":"MAT-2555 update parsers to use mongoid models v0.0.4","user":{"login":"adongare","id":23436747,"node_id":"MDQ6VXNlcjIzNDM2NzQ3","avatar_url":"https://avatars.githubusercontent.com/u/23436747?v=4","gravatar_id":"","url":"https://api.github.com/users/adongare","html_url":"https://github.com/adongare","followers_url":"https://api.github.com/users/adongare/followers","following_url":"https://api.github.com/users/adongare/following{/other_user}","gists_url":"https://api.github.com/users/adongare/gists{/gist_id}","starred_url":"https://api.github.com/users/adongare/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/adongare/subscriptions","organizations_url":"https://api.github.com/users/adongare/orgs","repos_url":"https://api.github.com/users/adongare/repos","events_url":"https://api.github.com/users/adongare/events{/privacy}","received_events_url":"https://api.github.com/users/adongare/received_events","type":"User","site_admin":false},"body":"MAT-2555 update parsers to use mongoid models v0.0.4\\r\\n\\r\\nPull requests into cqm-parsers require the following. Submitter and reviewer should :white_check_mark: when done. For items that are not-applicable, note it\'s not-applicable (\\"N/A\\") and :white_check_mark:.\\r\\n\\r\\n**Submitter:**\\r\\n- [ ] This pull request describes why these changes were made.\\r\\n- [ ] Internal ticket for this PR:\\r\\n- [ ] Internal ticket links to this PR\\r\\n- [ ] Code diff has been done and been reviewed\\r\\n- [ ] Tests are included and test edge cases\\r\\n- [ ] Tests have been run locally and pass\\r\\n\\r\\n**Reviewer 1:**\\r\\n\\r\\nName:\\r\\n- [ ] Code is maintainable and reusable, reuses existing code and infrastructure where appropriate, and accomplishes the task’s purpose\\r\\n- [ ] The tests appropriately test the new code, including edge cases\\r\\n- [ ] You have tried to break the code\\r\\n\\r\\n**Reviewer 2:**\\r\\n\\r\\nName:\\r\\n- [ ] Code is maintainable and reusable, reuses existing code and infrastructure where appropriate, and accomplishes the task’s purpose\\r\\n- [ ] The tests appropriately test the new code, including edge cases\\r\\n- [ ] You have tried to break the code\\r\\n","created_at":"2021-03-25T22:02:08Z","updated_at":"2021-03-25T22:02:08Z","closed_at":null,"merged_at":null,"merge_commit_sha":null,"assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[],"milestone":null,"draft":false,"commits_url":"https://api.github.com/repos/projecttacoma/cqm-parsers/pulls/142/commits","review_comments_url":"https://api.github.com/repos/projecttacoma/cqm-parsers/pulls/142/comments","review_comment_url":"https://api.github.com/repos/projecttacoma/cqm-parsers/pulls/comments{/number}","comments_url":"https://api.github.com/repos/projecttacoma/cqm-parsers/issues/142/comments","statuses_url":"https://api.github.com/repos/projecttacoma/cqm-parsers/statuses/43d76cddf11d6604ba4bc12cd4df181e44d425bf","head":{"label":"projecttacoma:MAT-2555","ref":"MAT-2555","sha":"43d76cddf11d6604ba4bc12cd4df181e44d425bf","user":{"login":"projecttacoma","id":549 ...

# %% [markdown]
# ![Oh good heavens gif, from gfycat](https://thumbs.gfycat.com/ColdAmbitiousDogwoodtwigborer-size_restricted.gif)

# %% [markdown]
# Obviously you're never going to just scan that quickly for any data you need, we need to wrangle that response to make it usable.
#
# But first, let's look at some of the other attributes of `requests.models.Response` objects.
#
# We can check out all of the attributes [here](https://requests.readthedocs.io/en/master/) in the documentation.

# %%
# Headers - another attribute, what does this show us?
r.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Thu, 25 Mar 2021 22:07:10 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"6ce362a3ce063419cb0d367fe998de2d7f04a9b17c90c56c5a1d3c87fd30cf19"', 'Last-Modified': 'Thu, 25 Mar 2021 22:02:09 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=9>; rel="last"', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '57', 'X-RateLimit-Reset': '1616711202', 'X-RateLimit-Used': '3', 'Accept-Ranges': 'bytes', 'Transfer-Encoding': 'chunked', 'X-GitHub-Request-Id': 'E842:7FDA:2B4FE4:47B5B1:605D098D'}

# %% [markdown]
# ### Checking out the status of your request

# %%
# Another attribute
r.status_code
# Out:
# 200

# %% [markdown]
# ### [Types of status codes](https://http.cat/)
#
# 1xx - Informational responses
#
# 2xx - Success
# - 200 OK
# - 201 Created
# - 204 No Content
#
# 3xx - Redirection
#
# - 301 Moved Permanently (permanent URL redirection)
# - 304 Not Modified (A conditional GET or HEAD request has been received and would have resulted in a 200 OK response if it were not for the fact that the condition evaluated to false.)
#
# 4xx - Client errors
#
# - 400 Bad Request
# - 401 Unauthorized
# - 403 Forbidden
# - 404 Not Found
#
# 5xx - Server errors
#
# - 500 Internal Server Error

# %%
# Get status code for a "broken" link

r_broken = requests.get('https://api.github.com/fake-ending')
r_broken.status_code
# Out:
# 404

# %% [markdown]
# Can also explictly ask for the returned format to be json as a method.

# %%
# Going back to our working request - how does this look, compared to text?
r.json()
# Out:
# [{'id': '15694452069',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 23436747,
#    'login': 'adongare',
#    'display_login': 'adongare',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/adongare',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23436747?'},
#   'repo': {'id': 116037332,
#    'name': 'projecttacoma/cqm-parsers',
#    'url': 'https://api.github.com/repos/projecttacoma/cqm-parsers'},
#   'payload': {'action': 'opened',
#    'number': 142,
#    'pull_request': {'url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/pulls/142',
#     'id': 601097061,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NjAxMDk3MDYx',
#     'html_url': 'https://github.com/projecttacoma/cqm-parsers/pull/142',
#     'diff_url': 'https://github.com/projecttacoma/cqm-parsers/pull/142.diff',
#     'patch_url': 'https://github.com/projecttacoma/cqm-parsers/pull/142.patch',
#     'issue_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/issues/142',
#     'number': 142,
#     'state': 'open',
#     'locked': False,
#     'title': 'MAT-2555 update parsers to use mongoid models v0.0.4',
#     'user': {'login': 'adongare',
#      'id': 23436747,
#      'node_id': 'MDQ6VXNlcjIzNDM2NzQ3',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/23436747?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/adongare',
#      'html_url': 'https://github.com/adongare',
#      'followers_url': 'https://api.github.com/users/adongare/followers',
#      'following_url': 'https://api.github.com/users/adongare/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/adongare/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/adongare/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/adongare/subscriptions',
#      'organizations_url': 'https://api.github.com/users/adongare/orgs',
#      'repos_url': 'https://api.github.com/users/adongare/repos',
#      'events_url': 'https://api.github.com/users/adongare/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/adongare/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'MAT-2555 update parsers to use mongoid models v0.0.4\r\n\r\nPull requests into cqm-parsers require the following. Submitter and reviewer should :white_check_mark: when done. For items that are not-applicable, note it\'s not-applicable ("N/A") and :white_check_mark:.\r\n\r\n**Submitter:**\r\n- [ ] This pull request describes why these changes were made.\r\n- [ ] Internal ticket for this PR:\r\n- [ ] Internal ticket links to this PR\r\n- [ ] Code diff has been done and been reviewed\r\n- [ ] Tests are included and test edge cases\r\n- [ ] Tests have been run locally and pass\r\n\r\n**Reviewer 1:**\r\n\r\nName:\r\n- [ ] Code is maintainable and reusable, reuses existing code and infrastructure where appropriate, and accomplishes the task’s purpose\r\n- [ ] The tests appropriately test the new code, including edge cases\r\n- [ ] You have tried to break the code\r\n\r\n**Reviewer 2:**\r\n\r\nName:\r\n- [ ] Code is maintainable and reusable, reuses existing code and infrastructure where appropriate, and accomplishes the task’s purpose\r\n- [ ] The tests appropriately test the new code, including edge cases\r\n- [ ] You have tried to break the code\r\n',
#     'created_at': '2021-03-25T22:02:08Z',
#     'updated_at': '2021-03-25T22:02:08Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/pulls/142/commits',
#     'review_comments_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/pulls/142/comments',
#     'review_comment_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/issues/142/comments',
#     'statuses_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/statuses/43d76cddf11d6604ba4bc12cd4df181e44d425bf',
#     'head': {'label': 'projecttacoma:MAT-2555',
#      'ref': 'MAT-2555',
#      'sha': '43d76cddf11d6604ba4bc12cd4df181e44d425bf',
#      'user': {'login': 'projecttacoma',
#       'id': 5497023,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU0OTcwMjM=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/5497023?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/projecttacoma',
#       'html_url': 'https://github.com/projecttacoma',
#       'followers_url': 'https://api.github.com/users/projecttacoma/followers',
#       'following_url': 'https://api.github.com/users/projecttacoma/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/projecttacoma/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/projecttacoma/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/projecttacoma/subscriptions',
#       'organizations_url': 'https://api.github.com/users/projecttacoma/orgs',
#       'repos_url': 'https://api.github.com/users/projecttacoma/repos',
#       'events_url': 'https://api.github.com/users/projecttacoma/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/projecttacoma/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 116037332,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMTYwMzczMzI=',
#       'name': 'cqm-parsers',
#       'full_name': 'projecttacoma/cqm-parsers',
#       'private': False,
#       'owner': {'login': 'projecttacoma',
#        'id': 5497023,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU0OTcwMjM=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/5497023?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/projecttacoma',
#        'html_url': 'https://github.com/projecttacoma',
#        'followers_url': 'https://api.github.com/users/projecttacoma/followers',
#        'following_url': 'https://api.github.com/users/projecttacoma/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/projecttacoma/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/projecttacoma/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/projecttacoma/subscriptions',
#        'organizations_url': 'https://api.github.com/users/projecttacoma/orgs',
#        'repos_url': 'https://api.github.com/users/projecttacoma/repos',
#        'events_url': 'https://api.github.com/users/projecttacoma/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/projecttacoma/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/projecttacoma/cqm-parsers',
#       'description': 'This project contains libraries for parsing HQMF documents and parsing MAT packages.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/projecttacoma/cqm-parsers',
#       'forks_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/forks',
#       'keys_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/teams',
#       'hooks_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/hooks',
#       'issue_events_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/events',
#       'assignees_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/tags',
#       'blobs_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/languages',
#       'stargazers_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/stargazers',
#       'contributors_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/contributors',
#       'subscribers_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/subscribers',
#       'subscription_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/subscription',
#       'commits_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/merges',
#       'archive_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/downloads',
#       'issues_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/deployments',
#       'created_at': '2018-01-02T16:56:24Z',
#       'updated_at': '2021-02-05T20:14:34Z',
#       'pushed_at': '2021-03-25T22:02:09Z',
#       'git_url': 'git://github.com/projecttacoma/cqm-parsers.git',
#       'ssh_url': 'git@github.com:projecttacoma/cqm-parsers.git',
#       'clone_url': 'https://github.com/projecttacoma/cqm-parsers.git',
#       'svn_url': 'https://github.com/projecttacoma/cqm-parsers',
#       'homepage': '',
#       'size': 31518,
#       'stargazers_count': 6,
#       'watchers_count': 6,
#       'language': 'Ruby',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 2,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 2,
#       'open_issues': 2,
#       'watchers': 6,
#       'default_branch': 'master'}},
#     'base': {'label': 'projecttacoma:bonnie-on-fhir',
#      'ref': 'bonnie-on-fhir',
#      'sha': 'c6fe55ad3775fe26ff61b32ae92dcd15ce9a2992',
#      'user': {'login': 'projecttacoma',
#       'id': 5497023,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU0OTcwMjM=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/5497023?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/projecttacoma',
#       'html_url': 'https://github.com/projecttacoma',
#       'followers_url': 'https://api.github.com/users/projecttacoma/followers',
#       'following_url': 'https://api.github.com/users/projecttacoma/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/projecttacoma/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/projecttacoma/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/projecttacoma/subscriptions',
#       'organizations_url': 'https://api.github.com/users/projecttacoma/orgs',
#       'repos_url': 'https://api.github.com/users/projecttacoma/repos',
#       'events_url': 'https://api.github.com/users/projecttacoma/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/projecttacoma/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 116037332,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMTYwMzczMzI=',
#       'name': 'cqm-parsers',
#       'full_name': 'projecttacoma/cqm-parsers',
#       'private': False,
#       'owner': {'login': 'projecttacoma',
#        'id': 5497023,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU0OTcwMjM=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/5497023?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/projecttacoma',
#        'html_url': 'https://github.com/projecttacoma',
#        'followers_url': 'https://api.github.com/users/projecttacoma/followers',
#        'following_url': 'https://api.github.com/users/projecttacoma/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/projecttacoma/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/projecttacoma/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/projecttacoma/subscriptions',
#        'organizations_url': 'https://api.github.com/users/projecttacoma/orgs',
#        'repos_url': 'https://api.github.com/users/projecttacoma/repos',
#        'events_url': 'https://api.github.com/users/projecttacoma/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/projecttacoma/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/projecttacoma/cqm-parsers',
#       'description': 'This project contains libraries for parsing HQMF documents and parsing MAT packages.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/projecttacoma/cqm-parsers',
#       'forks_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/forks',
#       'keys_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/teams',
#       'hooks_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/hooks',
#       'issue_events_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/events',
#       'assignees_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/tags',
#       'blobs_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/languages',
#       'stargazers_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/stargazers',
#       'contributors_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/contributors',
#       'subscribers_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/subscribers',
#       'subscription_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/subscription',
#       'commits_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/merges',
#       'archive_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/downloads',
#       'issues_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/projecttacoma/cqm-parsers/deployments',
#       'created_at': '2018-01-02T16:56:24Z',
#       'updated_at': '2021-02-05T20:14:34Z',
#       'pushed_at': '2021-03-25T22:02:09Z',
#       'git_url': 'git://github.com/projecttacoma/cqm-parsers.git',
#       'ssh_url': 'git@github.com:projecttacoma/cqm-parsers.git',
#       'clone_url': 'https://github.com/projecttacoma/cqm-parsers.git',
#       'svn_url': 'https://github.com/projecttacoma/cqm-parsers',
#       'homepage': '',
#       'size': 31518,
#       'stargazers_count': 6,
#       'watchers_count': 6,
#       'language': 'Ruby',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 2,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 2,
#       'open_issues': 2,
#       'watchers': 6,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/projecttacoma/cqm-parsers/pulls/142'},
#      'html': {'href': 'https://github.com/projecttacoma/cqm-parsers/pull/142'},
#      'issue': {'href': 'https://api.github.com/repos/projecttacoma/cqm-parsers/issues/142'},
#      'comments': {'href': 'https://api.github.com/repos/projecttacoma/cqm-parsers/issues/142/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/projecttacoma/cqm-parsers/pulls/142/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/projecttacoma/cqm-parsers/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/projecttacoma/cqm-parsers/pulls/142/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/projecttacoma/cqm-parsers/statuses/43d76cddf11d6604ba4bc12cd4df181e44d425bf'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 3,
#     'deletions': 9,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2021-03-25T22:02:09Z',
#   'org': {'id': 5497023,
#    'login': 'projecttacoma',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/projecttacoma',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5497023?'}},
#  {'id': '15694452066',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 78360817,
#    'login': 'MariaTeo',
#    'display_login': 'MariaTeo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MariaTeo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/78360817?'},
#   'repo': {'id': 222712214,
#    'name': 'codetapacademy/my-cv-v2-junior',
#    'url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior'},
#   'payload': {'action': 'opened',
#    'number': 282,
#    'pull_request': {'url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/pulls/282',
#     'id': 601097057,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NjAxMDk3MDU3',
#     'html_url': 'https://github.com/codetapacademy/my-cv-v2-junior/pull/282',
#     'diff_url': 'https://github.com/codetapacademy/my-cv-v2-junior/pull/282.diff',
#     'patch_url': 'https://github.com/codetapacademy/my-cv-v2-junior/pull/282.patch',
#     'issue_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/issues/282',
#     'number': 282,
#     'state': 'open',
#     'locked': False,
#     'title': 'Dev mariateo embeded Youtube video',
#     'user': {'login': 'MariaTeo',
#      'id': 78360817,
#      'node_id': 'MDQ6VXNlcjc4MzYwODE3',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/78360817?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/MariaTeo',
#      'html_url': 'https://github.com/MariaTeo',
#      'followers_url': 'https://api.github.com/users/MariaTeo/followers',
#      'following_url': 'https://api.github.com/users/MariaTeo/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/MariaTeo/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/MariaTeo/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/MariaTeo/subscriptions',
#      'organizations_url': 'https://api.github.com/users/MariaTeo/orgs',
#      'repos_url': 'https://api.github.com/users/MariaTeo/repos',
#      'events_url': 'https://api.github.com/users/MariaTeo/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/MariaTeo/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2021-03-25T22:02:08Z',
#     'updated_at': '2021-03-25T22:02:08Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/pulls/282/commits',
#     'review_comments_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/pulls/282/comments',
#     'review_comment_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/issues/282/comments',
#     'statuses_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/statuses/9f67b2cb1148fc0d2114288dde833f5920062a61',
#     'head': {'label': 'MariaTeo:dev-mariateo-yt',
#      'ref': 'dev-mariateo-yt',
#      'sha': '9f67b2cb1148fc0d2114288dde833f5920062a61',
#      'user': {'login': 'MariaTeo',
#       'id': 78360817,
#       'node_id': 'MDQ6VXNlcjc4MzYwODE3',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/78360817?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/MariaTeo',
#       'html_url': 'https://github.com/MariaTeo',
#       'followers_url': 'https://api.github.com/users/MariaTeo/followers',
#       'following_url': 'https://api.github.com/users/MariaTeo/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/MariaTeo/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/MariaTeo/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/MariaTeo/subscriptions',
#       'organizations_url': 'https://api.github.com/users/MariaTeo/orgs',
#       'repos_url': 'https://api.github.com/users/MariaTeo/repos',
#       'events_url': 'https://api.github.com/users/MariaTeo/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/MariaTeo/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 337533899,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMzc1MzM4OTk=',
#       'name': 'my-cv-v2-junior',
#       'full_name': 'MariaTeo/my-cv-v2-junior',
#       'private': False,
#       'owner': {'login': 'MariaTeo',
#        'id': 78360817,
#        'node_id': 'MDQ6VXNlcjc4MzYwODE3',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/78360817?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/MariaTeo',
#        'html_url': 'https://github.com/MariaTeo',
#        'followers_url': 'https://api.github.com/users/MariaTeo/followers',
#        'following_url': 'https://api.github.com/users/MariaTeo/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/MariaTeo/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/MariaTeo/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/MariaTeo/subscriptions',
#        'organizations_url': 'https://api.github.com/users/MariaTeo/orgs',
#        'repos_url': 'https://api.github.com/users/MariaTeo/repos',
#        'events_url': 'https://api.github.com/users/MariaTeo/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/MariaTeo/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/MariaTeo/my-cv-v2-junior',
#       'description': 'Build your online CV mastering how to write HTML and CSS efficiently',
#       'fork': True,
#       'url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior',
#       'forks_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/forks',
#       'keys_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/teams',
#       'hooks_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/hooks',
#       'issue_events_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/events',
#       'assignees_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/tags',
#       'blobs_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/languages',
#       'stargazers_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/stargazers',
#       'contributors_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/contributors',
#       'subscribers_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/subscribers',
#       'subscription_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/subscription',
#       'commits_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/merges',
#       'archive_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/downloads',
#       'issues_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/MariaTeo/my-cv-v2-junior/deployments',
#       'created_at': '2021-02-09T20:54:50Z',
#       'updated_at': '2021-02-11T19:16:15Z',
#       'pushed_at': '2021-03-25T21:59:15Z',
#       'git_url': 'git://github.com/MariaTeo/my-cv-v2-junior.git',
#       'ssh_url': 'git@github.com:MariaTeo/my-cv-v2-junior.git',
#       'clone_url': 'https://github.com/MariaTeo/my-cv-v2-junior.git',
#       'svn_url': 'https://github.com/MariaTeo/my-cv-v2-junior',
#       'homepage': None,
#       'size': 90826,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTk='},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'codetapacademy:dev-mariateo',
#      'ref': 'dev-mariateo',
#      'sha': 'dd9108234cc831a7e5289b03263fc51c59b03951',
#      'user': {'login': 'codetapacademy',
#       'id': 28319543,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI4MzE5NTQz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/28319543?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/codetapacademy',
#       'html_url': 'https://github.com/codetapacademy',
#       'followers_url': 'https://api.github.com/users/codetapacademy/followers',
#       'following_url': 'https://api.github.com/users/codetapacademy/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/codetapacademy/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/codetapacademy/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/codetapacademy/subscriptions',
#       'organizations_url': 'https://api.github.com/users/codetapacademy/orgs',
#       'repos_url': 'https://api.github.com/users/codetapacademy/repos',
#       'events_url': 'https://api.github.com/users/codetapacademy/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/codetapacademy/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 222712214,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjI3MTIyMTQ=',
#       'name': 'my-cv-v2-junior',
#       'full_name': 'codetapacademy/my-cv-v2-junior',
#       'private': False,
#       'owner': {'login': 'codetapacademy',
#        'id': 28319543,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI4MzE5NTQz',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/28319543?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/codetapacademy',
#        'html_url': 'https://github.com/codetapacademy',
#        'followers_url': 'https://api.github.com/users/codetapacademy/followers',
#        'following_url': 'https://api.github.com/users/codetapacademy/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/codetapacademy/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/codetapacademy/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/codetapacademy/subscriptions',
#        'organizations_url': 'https://api.github.com/users/codetapacademy/orgs',
#        'repos_url': 'https://api.github.com/users/codetapacademy/repos',
#        'events_url': 'https://api.github.com/users/codetapacademy/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/codetapacademy/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/codetapacademy/my-cv-v2-junior',
#       'description': 'Build your online CV mastering how to write HTML and CSS efficiently',
#       'fork': False,
#       'url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior',
#       'forks_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/forks',
#       'keys_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/teams',
#       'hooks_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/hooks',
#       'issue_events_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/events',
#       'assignees_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/tags',
#       'blobs_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/languages',
#       'stargazers_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/stargazers',
#       'contributors_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/contributors',
#       'subscribers_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/subscribers',
#       'subscription_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/subscription',
#       'commits_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/merges',
#       'archive_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/downloads',
#       'issues_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/deployments',
#       'created_at': '2019-11-19T14:14:57Z',
#       'updated_at': '2021-02-15T11:44:06Z',
#       'pushed_at': '2021-03-25T22:02:09Z',
#       'git_url': 'git://github.com/codetapacademy/my-cv-v2-junior.git',
#       'ssh_url': 'git@github.com:codetapacademy/my-cv-v2-junior.git',
#       'clone_url': 'https://github.com/codetapacademy/my-cv-v2-junior.git',
#       'svn_url': 'https://github.com/codetapacademy/my-cv-v2-junior',
#       'homepage': None,
#       'size': 195057,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 29,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 5,
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTk='},
#       'forks': 29,
#       'open_issues': 5,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/pulls/282'},
#      'html': {'href': 'https://github.com/codetapacademy/my-cv-v2-junior/pull/282'},
#      'issue': {'href': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/issues/282'},
#      'comments': {'href': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/issues/282/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/pulls/282/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/pulls/282/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/codetapacademy/my-cv-v2-junior/statuses/9f67b2cb1148fc0d2114288dde833f5920062a61'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': True,
#     'commits': 3,
#     'additions': 16,
#     'deletions': 3,
#     'changed_files': 3}},
#   'public': True,
#   'created_at': '2021-03-25T22:02:09Z',
#   'org': {'id': 28319543,
#    'login': 'codetapacademy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/codetapacademy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28319543?'}},
#  {'id': '15694452032',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 149103633,
#    'name': 'jinesh08/DemoDjango',
#    'url': 'https://api.github.com/repos/jinesh08/DemoDjango'},
#   'payload': {'action': 'opened',
#    'number': 13,
#    'pull_request': {'url': 'https://api.github.com/repos/jinesh08/DemoDjango/pulls/13',
#     'id': 601097053,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NjAxMDk3MDUz',
#     'html_url': 'https://github.com/jinesh08/DemoDjango/pull/13',
#     'diff_url': 'https://github.com/jinesh08/DemoDjango/pull/13.diff',
#     'patch_url': 'https://github.com/jinesh08/DemoDjango/pull/13.patch',
#     'issue_url': 'https://api.github.com/repos/jinesh08/DemoDjango/issues/13',
#     'number': 13,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump pyyaml from 3.11 to 5.4',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [pyyaml](https://github.com/yaml/pyyaml) from 3.11 to 5.4.\n<details>\n<summary>Changelog</summary>\n<p><em>Sourced from <a href="https://github.com/yaml/pyyaml/blob/master/CHANGES">pyyaml\'s changelog</a>.</em></p>\n<blockquote>\n<p>5.4 (2021-01-19)</p>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/yaml/pyyaml/pull/407">yaml/pyyaml#407</a> -- Build modernization, remove distutils, fix metadata, build wheels, CI to GHA</li>\n<li><a href="https://github-redirect.dependabot.com/yaml/pyyaml/pull/472">yaml/pyyaml#472</a> -- Fix for CVE-2020-14343, moves arbitrary python tags to UnsafeLoader</li>\n<li><a href="https://github-redirect.dependabot.com/yaml/pyyaml/pull/441">yaml/pyyaml#441</a> -- Fix memory leak in implicit resolver setup</li>\n<li><a href="https://github-redirect.dependabot.com/yaml/pyyaml/pull/392">yaml/pyyaml#392</a> -- Fix py2 copy support for timezone objects</li>\n<li><a href="https://github-redirect.dependabot.com/yaml/pyyaml/pull/378">yaml/pyyaml#378</a> -- Fix compatibility with Jython</li>\n</ul>\n<p>5.3.1 (2020-03-18)</p>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/yaml/pyyaml/pull/386">yaml/pyyaml#386</a> -- Prevents arbitrary code execution during python/object/new constructor</li>\n</ul>\n<p>5.3 (2020-01-06)</p>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/yaml/pyyaml/pull/290">yaml/pyyaml#290</a> -- Use <code>is</code> instead of equality for comparing with <code>None</code></li>\n<li><a href="https://github-redirect.dependabot.com/yaml/pyyaml/pull/270">yaml/pyyaml#270</a> -- Fix typos and stylistic nit</li>\n<li><a href="https://github-redirect.dependabot.com/yaml/pyyaml/pull/309">yaml/pyyaml#309</a> -- Fix up small typo</li>\n<li><a href="https://github-redirect.dependabot.com/yaml/pyyaml/pull/161">yaml/pyyaml#161</a> -- Fix handling of <strong>slots</strong></li>\n<li><a href="https://github-redirect.dependabot.com/yaml/pyyaml/pull/358">yaml/pyyaml#358</a> -- Allow calling add_multi_constructor with None</li>\n<li><a href="https://github-redirect.dependabot.com/yaml/pyyaml/pull/285">yaml/pyyaml#285</a> -- Add use of safe_load() function in README</li>\n<li><a href="https://github-redirect.dependabot.com/yaml/pyyaml/pull/351">yaml/pyyaml#351</a> -- Fix reader for Unicode code points over 0xFFFF</li>\n<li><a href="https://github-redirect.dependabot.com/yaml/pyyaml/pull/360">yaml/pyyaml#360</a> -- Enable certain unicode tests when maxunicode not &gt; 0xffff</li>\n<li><a href="https://github-redirect.dependabot.com/yaml/pyyaml/pull/359">yaml/pyyaml#359</a> -- Use full_load in yaml-highlight example</li>\n<li><a href="https://github-redirect.dependabot.com/yaml/pyyaml/pull/244">yaml/pyyaml#244</a> -- Document that PyYAML is implemented with Cython</li>\n<li><a href="https://github-redirect.dependabot.com/yaml/pyyaml/pull/329">yaml/pyyaml#329</a> -- Fix for Python 3.10</li>\n<li><a href="https://github-redirect.dependabot.com/yaml/pyyaml/pull/310">yaml/pyyaml#310</a> -- Increase size of index, line, and column fields</li>\n<li><a href="https://github-redirect.dependabot.com/yaml/pyyaml/pull/260">yaml/pyyaml#260</a> -- Remove some unused imports</li>\n<li><a href="https://github-redirect.dependabot.com/yaml/pyyaml/pull/163">yaml/pyyaml#163</a> -- Create timezone-aware datetimes when parsed as such</li>\n<li><a href="https://github-redirect.dependabot.com/yaml/pyyaml/pull/363">yaml/pyyaml#363</a> -- Add tests for timezone</li>\n</ul>\n<h2>5.2 (2019-12-02)</h2>\n<ul>\n<li>Repair incompatibilities introduced with 5.1. The default Loader was changed,\nbut several methods like add_constructor still used the old default\n<a href="https://github-redirect.dependabot.com/yaml/pyyaml/pull/279">yaml/pyyaml#279</a> -- A more flexible fix for custom tag constructors\n<a href="https://github-redirect.dependabot.com/yaml/pyyaml/pull/287">yaml/pyyaml#287</a> -- Change default loader for yaml.add_constructor\n<a href="https://github-redirect.dependabot.com/yaml/pyy ...
#     'created_at': '2021-03-25T22:02:08Z',
#     'updated_at': '2021-03-25T22:02:08Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '31a30d5f94755868d757a8cfb65e3692645b3b9e',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/jinesh08/DemoDjango/pulls/13/commits',
#     'review_comments_url': 'https://api.github.com/repos/jinesh08/DemoDjango/pulls/13/comments',
#     'review_comment_url': 'https://api.github.com/repos/jinesh08/DemoDjango/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/jinesh08/DemoDjango/issues/13/comments',
#     'statuses_url': 'https://api.github.com/repos/jinesh08/DemoDjango/statuses/00f215941d35d2938955fda13a81c4e5873bcd7b',
#     'head': {'label': 'jinesh08:dependabot/pip/pyyaml-5.4',
#      'ref': 'dependabot/pip/pyyaml-5.4',
#      'sha': '00f215941d35d2938955fda13a81c4e5873bcd7b',
#      'user': {'login': 'jinesh08',
#       'id': 32705404,
#       'node_id': 'MDQ6VXNlcjMyNzA1NDA0',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/32705404?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jinesh08',
#       'html_url': 'https://github.com/jinesh08',
#       'followers_url': 'https://api.github.com/users/jinesh08/followers',
#       'following_url': 'https://api.github.com/users/jinesh08/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jinesh08/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jinesh08/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jinesh08/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jinesh08/orgs',
#       'repos_url': 'https://api.github.com/users/jinesh08/repos',
# ...
#        'subscriptions_url': 'https://api.github.com/users/Couchers-org/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Couchers-org/orgs',
#        'repos_url': 'https://api.github.com/users/Couchers-org/repos',
#        'events_url': 'https://api.github.com/users/Couchers-org/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Couchers-org/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/Couchers-org/couchers',
#       'description': 'Couchers.org',
#       'fork': False,
#       'url': 'https://api.github.com/repos/Couchers-org/couchers',
#       'forks_url': 'https://api.github.com/repos/Couchers-org/couchers/forks',
#       'keys_url': 'https://api.github.com/repos/Couchers-org/couchers/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Couchers-org/couchers/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Couchers-org/couchers/teams',
#       'hooks_url': 'https://api.github.com/repos/Couchers-org/couchers/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Couchers-org/couchers/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Couchers-org/couchers/events',
#       'assignees_url': 'https://api.github.com/repos/Couchers-org/couchers/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Couchers-org/couchers/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Couchers-org/couchers/tags',
#       'blobs_url': 'https://api.github.com/repos/Couchers-org/couchers/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Couchers-org/couchers/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Couchers-org/couchers/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Couchers-org/couchers/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Couchers-org/couchers/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Couchers-org/couchers/languages',
#       'stargazers_url': 'https://api.github.com/repos/Couchers-org/couchers/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Couchers-org/couchers/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Couchers-org/couchers/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Couchers-org/couchers/subscription',
#       'commits_url': 'https://api.github.com/repos/Couchers-org/couchers/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Couchers-org/couchers/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Couchers-org/couchers/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Couchers-org/couchers/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Couchers-org/couchers/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Couchers-org/couchers/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Couchers-org/couchers/merges',
#       'archive_url': 'https://api.github.com/repos/Couchers-org/couchers/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Couchers-org/couchers/downloads',
#       'issues_url': 'https://api.github.com/repos/Couchers-org/couchers/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Couchers-org/couchers/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Couchers-org/couchers/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Couchers-org/couchers/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Couchers-org/couchers/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Couchers-org/couchers/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Couchers-org/couchers/deployments',
#       'created_at': '2020-05-20T13:08:31Z',
#       'updated_at': '2021-03-25T18:00:20Z',
#       'pushed_at': '2021-03-25T17:25:59Z',
#       'git_url': 'git://github.com/Couchers-org/couchers.git',
#       'ssh_url': 'git@github.com:Couchers-org/couchers.git',
#       'clone_url': 'https://github.com/Couchers-org/couchers.git',
#       'svn_url': 'https://github.com/Couchers-org/couchers',
#       'homepage': 'https://couchers.org',
#       'size': 48370,
#       'stargazers_count': 31,
#       'watchers_count': 31,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 8,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 81,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 8,
#       'open_issues': 81,
#       'watchers': 31,
#       'default_branch': 'develop'}},
#     'base': {'label': 'Couchers-org:backend/feature/references',
#      'ref': 'backend/feature/references',
#      'sha': 'e781ffc5393b4279655c32594a28c7e1b339749e',
#      'user': {'login': 'Couchers-org',
#       'id': 67369976,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY3MzY5OTc2',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/67369976?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Couchers-org',
#       'html_url': 'https://github.com/Couchers-org',
#       'followers_url': 'https://api.github.com/users/Couchers-org/followers',
#       'following_url': 'https://api.github.com/users/Couchers-org/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Couchers-org/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Couchers-org/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Couchers-org/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Couchers-org/orgs',
#       'repos_url': 'https://api.github.com/users/Couchers-org/repos',
#       'events_url': 'https://api.github.com/users/Couchers-org/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Couchers-org/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 265568565,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNjU1Njg1NjU=',
#       'name': 'couchers',
#       'full_name': 'Couchers-org/couchers',
#       'private': False,
#       'owner': {'login': 'Couchers-org',
#        'id': 67369976,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY3MzY5OTc2',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/67369976?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Couchers-org',
#        'html_url': 'https://github.com/Couchers-org',
#        'followers_url': 'https://api.github.com/users/Couchers-org/followers',
#        'following_url': 'https://api.github.com/users/Couchers-org/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Couchers-org/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Couchers-org/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Couchers-org/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Couchers-org/orgs',
#        'repos_url': 'https://api.github.com/users/Couchers-org/repos',
#        'events_url': 'https://api.github.com/users/Couchers-org/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Couchers-org/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/Couchers-org/couchers',
#       'description': 'Couchers.org',
#       'fork': False,
#       'url': 'https://api.github.com/repos/Couchers-org/couchers',
#       'forks_url': 'https://api.github.com/repos/Couchers-org/couchers/forks',
#       'keys_url': 'https://api.github.com/repos/Couchers-org/couchers/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Couchers-org/couchers/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Couchers-org/couchers/teams',
#       'hooks_url': 'https://api.github.com/repos/Couchers-org/couchers/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Couchers-org/couchers/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Couchers-org/couchers/events',
#       'assignees_url': 'https://api.github.com/repos/Couchers-org/couchers/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Couchers-org/couchers/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Couchers-org/couchers/tags',
#       'blobs_url': 'https://api.github.com/repos/Couchers-org/couchers/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Couchers-org/couchers/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Couchers-org/couchers/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Couchers-org/couchers/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Couchers-org/couchers/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Couchers-org/couchers/languages',
#       'stargazers_url': 'https://api.github.com/repos/Couchers-org/couchers/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Couchers-org/couchers/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Couchers-org/couchers/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Couchers-org/couchers/subscription',
#       'commits_url': 'https://api.github.com/repos/Couchers-org/couchers/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Couchers-org/couchers/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Couchers-org/couchers/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Couchers-org/couchers/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Couchers-org/couchers/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Couchers-org/couchers/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Couchers-org/couchers/merges',
#       'archive_url': 'https://api.github.com/repos/Couchers-org/couchers/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Couchers-org/couchers/downloads',
#       'issues_url': 'https://api.github.com/repos/Couchers-org/couchers/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Couchers-org/couchers/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Couchers-org/couchers/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Couchers-org/couchers/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Couchers-org/couchers/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Couchers-org/couchers/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Couchers-org/couchers/deployments',
#       'created_at': '2020-05-20T13:08:31Z',
#       'updated_at': '2021-03-25T18:00:20Z',
#       'pushed_at': '2021-03-25T17:25:59Z',
#       'git_url': 'git://github.com/Couchers-org/couchers.git',
#       'ssh_url': 'git@github.com:Couchers-org/couchers.git',
#       'clone_url': 'https://github.com/Couchers-org/couchers.git',
#       'svn_url': 'https://github.com/Couchers-org/couchers',
#       'homepage': 'https://couchers.org',
#       'size': 48370,
#       'stargazers_count': 31,
#       'watchers_count': 31,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 8,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 81,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 8,
#       'open_issues': 81,
#       'watchers': 31,
#       'default_branch': 'develop'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Couchers-org/couchers/pulls/847'},
#      'html': {'href': 'https://github.com/Couchers-org/couchers/pull/847'},
#      'issue': {'href': 'https://api.github.com/repos/Couchers-org/couchers/issues/847'},
#      'comments': {'href': 'https://api.github.com/repos/Couchers-org/couchers/issues/847/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Couchers-org/couchers/pulls/847/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Couchers-org/couchers/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Couchers-org/couchers/pulls/847/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Couchers-org/couchers/statuses/f6bcb7b541efa8212c4ef47e25ac7d5d86e00e7f'}},
#     'author_association': 'MEMBER',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2021-03-25T21:45:22Z',
#   'org': {'id': 67369976,
#    'login': 'Couchers-org',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Couchers-org',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67369976?'}},
#  {'id': '15694451952',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 123867686,
#    'name': 'janselva/pnda',
#    'url': 'https://api.github.com/repos/janselva/pnda'},
#   'payload': {'ref': 'dependabot/pip/mirror/dependencies/pyyaml-5.4',
#    'ref_type': 'branch',
#    'master_branch': 'develop',
#    'description': 'Release notes and resources for building PNDA',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-03-25T22:02:09Z'},
#  {'id': '15694451931',
#   'type': 'CreateEvent',
#   'actor': {'id': 80783004,
#    'login': 'grosuionutandrei',
#    'display_login': 'grosuionutandrei',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/grosuionutandrei',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80783004?'},
#   'repo': {'id': 351587313,
#    'name': 'grosuionutandrei/temaThreads',
#    'url': 'https://api.github.com/repos/grosuionutandrei/temaThreads'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-03-25T22:02:08Z'},
#  {'id': '15694451930',
#   'type': 'PushEvent',
#   'actor': {'id': 12897448,
#    'login': 'theqp',
#    'display_login': 'theqp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/theqp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12897448?'},
#   'repo': {'id': 331243177,
#    'name': 'ilgon-technologies/ilgon-wallet-page',
#    'url': 'https://api.github.com/repos/ilgon-technologies/ilgon-wallet-page'},
#   'payload': {'push_id': 6787754732,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6356a21267f3f4f77ab3f94df09409738ec0d05b',
#    'before': 'd6daa8eb0e811af7a3554e27d9b3fc283088c169',
#    'commits': [{'sha': '6356a21267f3f4f77ab3f94df09409738ec0d05b',
#      'author': {'email': 'hhpkoop@gmail.com', 'name': 'Koppany Papp'},
#      'message': 'deploy 396e82a7',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ilgon-technologies/ilgon-wallet-page/commits/6356a21267f3f4f77ab3f94df09409738ec0d05b'}]},
#   'public': True,
#   'created_at': '2021-03-25T22:02:08Z',
#   'org': {'id': 77759772,
#    'login': 'ilgon-technologies',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ilgon-technologies',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77759772?'}}]

# %% [markdown]
# #### A note on errors and exceptions with the Requests library
#
# There are a number of exceptions and error codes you need to be familiar with when using the Requests library in Python.
#
# - The Requests library will raise a ConnectionError exception if there is a network problem like a DNS failure, or refused connection
# - These are rare, but with invalid HTTP responses, Requests will also raise an HTTPError exception
# - A Timeout exception will be raised if a request times out
# - If and when a request exceeds the preconfigured number of maximum redirections, then a TooManyRedirects exception will be raised

# %% [markdown]
# ## Another Way to Deal with APIs
#
# Check out [Postman](https://www.getpostman.com/).

# %% [markdown]
# # Gotta Catch 'Em All! Using the Pokemon API
#
# https://pokeapi.co/
#
# Nice place to start because there's no login details or credentials to fuss with
#
# For now, just want to explore grabbing the Types of different Pokemon.
#
# Useful documentation links:
# - Pokemon endpoint: https://pokeapi.co/docs/v2#pokemon
#     - `https://pokeapi.co/api/v2/pokemon/{id or name}/`
# - Type endpoint: https://pokeapi.co/docs/v2#types
#     - `https://pokeapi.co/api/v2/type/{id or name}/`

# %% [markdown]
# ### Start by exploring the response from the Pokemon endpoint
#
# Going to start with Charmander, pokemon #4, cause he's one of my favorites
#
# <img src="https://i.pinimg.com/originals/e7/0e/d0/e70ed0b54f9230c56c2e3bd2958d68a4.jpg" alt="adorable charmander found via pinterest" width=150>
#
# [Image Source](https://www.pinterest.com/pin/419045940312305352/)

# %%
# First, what endpoint url are we using?
base_poke_url = "https://pokeapi.co/api/v2/pokemon/"

# %%
# How does that need to adapt for charmander?
pokemon_name = 'charmander'
char_url = f"{base_poke_url}{pokemon_name}/"

# %%
char_url
# Out:
# 'https://pokeapi.co/api/v2/pokemon/charmander/'

# %%
# Check the status code, will this work?
requests.get(char_url).status_code
# Out:
# 200

# %%
# Now let's actually get the response
char_resp = requests.get(char_url).json()

# %%
type(char_resp)
# Out:
# dict

# %%
# Let's check out some details about the response
char_resp.keys()
# Out:
# dict_keys(['abilities', 'base_experience', 'forms', 'game_indices', 'height', 'held_items', 'id', 'is_default', 'location_area_encounters', 'moves', 'name', 'order', 'past_types', 'species', 'sprites', 'stats', 'types', 'weight'])

# %%
char_resp['id']
# Out:
# 4

# %%
char_resp['name']
# Out:
# 'charmander'

# %%
char_resp['types']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-50-0e44f742ad3c> in <module>
# ----> 1 char_resp['types'][1]['type']['name']
#
# IndexError: list index out of range

# %%
bulba_resp = requests.get( f"{base_poke_url}bulbasaur/").json()

# %%
len(bulba_resp['types'])
# Out:
# 2

# %% [markdown]
# #### Challenge!
#
# Let's write a function that, given a response from this API's pokemon endpoint, returns a list of the ID, name, primary type and secondary type for that pokemon.

# %%
def get_pokemon_details(poke_resp):
    '''
    inputs:
    poke_resp - expects json/dict
    
    outputs: 
    list of id, pokemon name, primary type and secondary type 
    '''
    result = []
    
    # add id number
    result.append(poke_resp['id'])
    # add name
    result.append(poke_resp['name'])
    # add primary type name
    result.append(poke_resp['types'][0]['type']['name'])
    
    num_types = len(poke_resp['types'])
    
    if num_types == 1:
        result.append("None") # add none for secondary type if they don't have one
    else:
        result.append(poke_resp['types'][1]['type']['name'])
    
    return result

# %%
# Let's test our function on the 3 original starter pokemon
original_starter_numbers = [1, 4, 7]

# %%
for poke_id in original_starter_numbers:
    url = f"{base_poke_url}{poke_id}/"
    r = requests.get(url).json()
    details = get_pokemon_details(r)
    print(details)
# Out:
# [1, 'bulbasaur', 'grass', 'poison']
# [4, 'charmander', 'fire', 'None']
# [7, 'squirtle', 'water', 'None']

# %% [markdown]
# ### Moving to Pandas
#
# Let's get all of these details for all of the original 151 pokemon! And save them to a Pandas dataframe.

# %%
# Need to import pandas
import pandas as pd

# %%
# Let's go ahead and define what our columns will be
col_names = ['id', 'name', 'primary_type', 'secondary_type']

# %%
# Define a list of our 151 pokemon ids
original_151 = list(range(1, 152))

# %% [markdown]
# So we're going to make 151 requests... don't want to overload the API endpoint! So let's use the time library to space out our requests.

# %%
import time

# %%
# Easiest way to do this will be to have a list of lists, then concat them all

# Define a blank list to capture all the pokemon details
row_list = []
# And then loop over our pokemon ids!
for poke_id in original_151:
    url = f"{base_poke_url}{poke_id}"
    resp = requests.get(url).json()
    details = get_pokemon_details(resp)
    row_list.append(details)
    time.sleep(.5)

# %%
# Then, concat everything into one df
# Reference: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.append.html
poke_df = pd.concat([pd.DataFrame([i], columns=col_names) for i in row_list], ignore_index=True)

# %%
poke_df
# Out:
#       id        name primary_type secondary_type
# 0      1   bulbasaur        grass         poison
# 1      2     ivysaur        grass         poison
# 2      3    venusaur        grass         poison
# 3      4  charmander         fire           None
# 4      5  charmeleon         fire           None
# ..   ...         ...          ...            ...
# 146  147     dratini       dragon           None
# 147  148   dragonair       dragon           None
# 148  149   dragonite       dragon         flying
# 149  150      mewtwo      psychic           None
# 150  151         mew      psychic           None
#
# [151 rows x 4 columns]

# %%
# visualize it!
import matplotlib.pyplot as plt

# Let's plot a bar graph of our primary types
primary_types = poke_df.groupby('primary_type').count()['id'].sort_values(ascending=True)

# %%
primary_types
# Out:
# primary_type
# fairy        2
# ice          2
# dragon       3
# ghost        3
# fighting     7
# ground       8
# psychic      8
# electric     9
# rock         9
# bug         12
# fire        12
# grass       12
# poison      14
# normal      22
# water       28
# Name: id, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.barh(y=primary_types.index, width= primary_types)
# plt.xticks(rotation=45);
# Out:
# <BarContainer object of 15 artists>

# %% [markdown]
# ![monty python gif - and now for something completely different, from giphy](https://media.giphy.com/media/xznyPebL28X5u/giphy.gif)

# %% [markdown]
# # Movie Time!
#
# Let's practice with an API that actually requires some authorization, in the form of an API Key!

# %% [markdown]
# # **NEVER EVER PUT YOUR API KEY ON GITHUB**
#
# Either create a json file with API keys in a different directory, or create a python file with the key saved as a variable that you can call. (There are even more options than that, but these are two easily-accessible ones)

# %%
# Option 1: use a json file saved to some other folder outside your Git repo
# In a new terminal window create a file called api.json and save the path to that file

# Need to import json to do this
import json

# Define a function to open the json
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# Using the function to open and load all keys in that file 
api_keys = get_keys("/Users/lberlin/secrets/api.json")

# Setting the first (and only) value as a variable
tmdb_key_1 = api_keys['tmdb_key']

# %%
# !ls
# Out:
# 00-Orientation-Slides.pdf
# 01-WhatIsDataScience-Slides.pdf
# 02-Terminal-Git-GitHub-Slides.pdf
# 03-Python-Loops-and-Functions.ipynb
# 03-Python-Loops-and-Functions_complete.ipynb
# 04-Introducing-Numpy-And-Pandas.ipynb
# 04-Introducing-Numpy-And-Pandas_complete.ipynb
# 05-Pandas-Practice_complete.ipynb
# 06-DataVisualizationDosAndDonts.pdf
# 06-Visualization-with-Matplotlib-and-Seaborn_complete.ipynb
# 07-SQL-to-Pandas_complete.ipynb
# 08-NoSQL-and-MongoDB_complete.ipynb
# 09-API-Requests.ipynb
# CL-06-DataVisualizations.ipynb
# CL-07-SQL.ipynb
# README.md
# complete_notebooks
# data
# example_horizontal_barchart_with_percentages.png
# images
# keys.py

# %%
# Option 2: use a python file that's been added to your .gitignore

# In a new terminal window, create a file called keys.py in this repo
# Save the api key as tmdb_api_key = "[key]"

from keys import tmdb_key

tmdb_key_2 = tmdb_key

# Then let's edit our .gitignore file together

# %% [markdown]
# Just as important! You may want to call the variable you've set to check that the API key is rendering correctly - but **be sure to clear the output of that cell** or else the output will show your key! And then if you push to GitHub it'll push that output to the internet which defeats the whole point of saving your key elsewhere!

# %% [markdown]
# ### And now, accessing movie data
#
# Documentation: https://developers.themoviedb.org/3

# %%
# Default URL given as an example... let's see what it is!
test_url = f"https://api.themoviedb.org/3/movie/550?api_key={tmdb_key_1}"

# %%
# Let's get the response and explore it
resp = requests.get(test_url).json()

# %%
resp
# Out:
# {'adult': False,
#  'backdrop_path': '/52AfXWuXCHn3UjD17rBruA9f5qb.jpg',
#  'belongs_to_collection': None,
#  'budget': 63000000,
#  'genres': [{'id': 18, 'name': 'Drama'}],
#  'homepage': 'http://www.foxmovies.com/movies/fight-club',
#  'id': 550,
#  'imdb_id': 'tt0137523',
#  'original_language': 'en',
#  'original_title': 'Fight Club',
#  'overview': 'A ticking-time-bomb insomniac and a slippery soap salesman channel primal male aggression into a shocking new form of therapy. Their concept catches on, with underground "fight clubs" forming in every town, until an eccentric gets in the way and ignites an out-of-control spiral toward oblivion.',
#  'popularity': 41.208,
#  'poster_path': '/8kNruSfhk5IoE4eZOc4UpvDn6tq.jpg',
#  'production_companies': [{'id': 508,
#    'logo_path': '/7PzJdsLGlR7oW4J0J5Xcd0pHGRg.png',
#    'name': 'Regency Enterprises',
#    'origin_country': 'US'},
#   {'id': 711,
#    'logo_path': '/tEiIH5QesdheJmDAqQwvtN60727.png',
#    'name': 'Fox 2000 Pictures',
#    'origin_country': 'US'},
#   {'id': 20555,
#    'logo_path': '/hD8yEGUBlHOcfHYbujp71vD8gZp.png',
#    'name': 'Taurus Film',
#    'origin_country': 'DE'},
#   {'id': 54051,
#    'logo_path': None,
#    'name': 'Atman Entertainment',
#    'origin_country': ''},
#   {'id': 54052,
#    'logo_path': None,
#    'name': 'Knickerbocker Films',
#    'origin_country': 'US'},
#   {'id': 25,
#    'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png',
#    'name': '20th Century Fox',
#    'origin_country': 'US'},
#   {'id': 4700,
#    'logo_path': '/A32wmjrs9Psf4zw0uaixF0GXfxq.png',
#    'name': 'The Linson Company',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'DE', 'name': 'Germany'},
#   {'iso_3166_1': 'US', 'name': 'United States of America'}],
#  'release_date': '1999-10-15',
#  'revenue': 100853753,
#  'runtime': 139,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Mischief. Mayhem. Soap.',
#  'title': 'Fight Club',
#  'video': False,
#  'vote_average': 8.4,
#  'vote_count': 21387}

# %%
resp['original_title']
# Out:
# 'Fight Club'

# %%
# Find similar movies to the previous id

# %%
# How many similar movies did it find?

# %%
# but is that the length of these results?

# %%
# what's in here?

# %% [markdown]
# -----
#
# ## Extra Credit - Further Practice
#
# There are many ways to access data through APIs! [Sodapy](https://github.com/xmunoz/sodapy) is the Python client for the Socrata Open Data API.

# %%
# Install before running 
# !pip install sodapy

# %% [markdown]
# #### Tokenize yourself!
#
# https://dev.socrata.com/foundry/data.cityofnewyork.us/fhrw-4uyv
#
# Scroll down and click to sign up for an app token! No credit cards required!

# %%
token = '' # paste your token here 

from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", token)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("fhrw-4uyv", incident_zip = '11004', limit=1000)

# %%
type(results)

# %%
len(results)

# %%
results[0]

# %%
df_soda = pd.DataFrame(results)

print(len(df_soda))
print(df_soda.columns)
df_soda.head()

# %% [markdown]
# ## Even Further Practice
#
# https://github.com/toddmotto/public-apis
#
# Find a buddy, find a free api, get a key, and do a GET. Try to transform the response into a dataframe.
